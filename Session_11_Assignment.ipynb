# %% [markdown]
# <a href="https://colab.research.google.com/github/tapasML/EVAB2_Session_11/blob/main/Session_11_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Load the controller module (main.py)
#
# ---

# %%
import main
from main import *

# %% [markdown]
# # Load data (dataloader.py)
#
# ---

# %%
loaddata()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# # Display few images from training data (utils.py)
#
# ---

# %%
displaysampleimage()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# shape of images torch.Size([512, 3, 32, 32])
# truck  bird  deer  bird

# %% [markdown]
# # Define a Resnet18 model and create one (model_resnet.py)
#
# ---

# %%
# training module create a Resnet18 model
model = createmodel()

# %% [markdown]
# # Plot Cyclic LR with assumed LRMax and LRMin
#
# ---

# %%
# initail LR=0.001, max_lr=1.0, step_size_up=20 (24 epochs * 5)
plot_CLR_graph(model)

# %% [markdown]
# # Display model summary for image. (training.py)
#
# ---

# %%
# training module prints model summary
summary(model, input_size=(3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3          [-1, 128, 32, 32]          73,728
#        BatchNorm2d-4          [-1, 128, 16, 16]             256
#             Conv2d-5          [-1, 128, 16, 16]         147,456
#        BatchNorm2d-6          [-1, 128, 16, 16]             256
#             Conv2d-7          [-1, 128, 16, 16]         147,456
#        BatchNorm2d-8          [-1, 128, 16, 16]             256
#         BasicBlock-9          [-1, 128, 16, 16]               0
#            Conv2d-10          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-11          [-1, 128, 16, 16]             256
#            Conv2d-12          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-13          [-1, 128, 16, 16]             256
# ...

# %% [markdown]
# # LR Range Test to find LR_Max for given # of epochs
#
# ---

# %%
resetOptimizer()
plotLRRangeTest_graph(3)
# Out:
# torch.Size([512, 3, 32, 32]) torch.Size([512])
# [1,    40] loss: 0.043
# [1,    80] loss: 0.040
# Epoch = 0, Training Accuracy:  26.72, Test Accuracy: 33.89
# torch.Size([512, 3, 32, 32]) torch.Size([512])
# [2,    40] loss: 0.038
# [2,    80] loss: 0.037
# Epoch = 1, Training Accuracy:  33.98, Test Accuracy: 37.90
# torch.Size([512, 3, 32, 32]) torch.Size([512])
# [3,    40] loss: 0.035

# %% [markdown]
# # Prepare to train the model. Reset and re-define loss function, optimizer, scheduler (training.py)
#
# ---

# %%
resetOptimizer()

# %% [markdown]
# # Plot One Cycle Graph with learning rate found
# ---

# %%
plot_OneCycle_graph(model)

# %% [markdown]
# # Train and Test model for given number of epochs
#
# ---

# %%
resetOptimizer()
model = trainmodel(24)
# Out:
# torch.Size([512, 3, 32, 32]) torch.Size([512])
# [1,    40] loss: 0.040
# [1,    80] loss: 0.031
# Epoch = 0, Training Accuracy:  37.87, Test Accuracy: 53.75
# torch.Size([512, 3, 32, 32]) torch.Size([512])
# [2,    40] loss: 0.026
# [2,    80] loss: 0.023
# Epoch = 1, Training Accuracy:  56.93, Test Accuracy: 65.57
# torch.Size([512, 3, 32, 32]) torch.Size([512])
# [3,    40] loss: 0.019
# [3,    80] loss: 0.018
# Epoch = 2, Training Accuracy:  67.63, Test Accuracy: 70.37
# torch.Size([512, 3, 32, 32]) torch.Size([512])
# [4,    40] loss: 0.016
# [4,    80] loss: 0.015
# Epoch = 3, Training Accuracy:  74.12, Test Accuracy: 78.60
# torch.Size([512, 3, 32, 32]) torch.Size([512])
# [5,    40] loss: 0.013
# [5,    80] loss: 0.012
# Epoch = 4, Training Accuracy:  78.79, Test Accuracy: 81.16
# torch.Size([512, 3, 32, 32]) torch.Size([512])
# [6,    40] loss: 0.011
# [6,    80] loss: 0.010
# Epoch = 5, Training Accuracy:  81.82, Test Accuracy: 83.08
# ...

# %% [markdown]
# # Display 25 misclassified images (utils.py)

# %%
displaymisclassified()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %% [markdown]
# # Plot Accuract Graph
#
# ---

# %%
plotAccuracy()
